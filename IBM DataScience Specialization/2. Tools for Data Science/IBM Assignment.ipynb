# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# __Mehul Srivastava__
# - Engineering Fresher

# %% [markdown]
# *I am interested in data science because I ike mathematics*

# %% [markdown]
# ### This following code does ground breaking stuff, adding 60 to 9, it's a thing of science fiction tbh

# %%
60 + 9
# Out:
# 69

# %% [markdown]
# 1. First  Point
# 2. Second Point
# 3. Third  Point

# %% [markdown]
# ____________________

# %% [markdown]
# - this
# - is
# - also
# - a
# - list
# - lmao

# %% [markdown]
# | Student | Grade |
# | ---   | ---  |
# | Me | 99 |
# | You :) | 100 |

# %% [markdown]
# >*\"Don't ever trust Java\"* -Elon Musk, Inventor of JavaScript
